# %% [markdown]
# # Basic Wind Turbine Simulation
#
# * A basic wind turbine simulation can be performed
# * Requires known wind speeds
# * A power curve can be supplied directly, or a synthetic power curve can be automatically generated

# %%
import reskit as rk
from reskit import windpower

# %%
# Set some constants for later

TURBINE_CAPACITY = 4200 # kW
TURBINE_HUB_HEIGHT = 120 # meters
TURBINE_ROTOR_DIAMETER = 136 # meters
TURBINE_LOCATION = (6.0,50.5) # (lon, lat)

# %% [markdown]
# # Simulate turbine directly with known wind speed data

# %%
windspeeds = [5.384,  5.323,  5.232,  5.161,  5.439,  6.045,  6.417,  6.611, 6.831,  6.589,  6.929,  7.571,  7.543,  
              7.12 ,  7.536,  8.757, 9.776,  9.952, 10.326, 10.875, 11.239, 11.665, 12.086, 12.48 ,12.727, 12.969, 
              13.243, 13.53 , 13.658, 13.339, 12.723, 12.11 ,11.674, 10.8  , 10.696,  9.721,  9.133,  9.581,  9.528,  
              9.686, 9.492,  9.004,  8.48 ,  8.159,  7.918,  7.692,  7.204,  7.092, 6.887,  6.568,  6.532,  6.841,  
              7.354,  7.579,  7.588,  7.859, 8.2  ,  7.847,  6.918,  6.289,  6.222,  6.223,  5.78 ,  5.217, 4.379,  
              4.292,  5.725,  6.609,  5.364,  4.901,  5.979]

capacity_factors = windpower.simulateTurbine(windspeed=windspeeds, 
                                             capacity=TURBINE_CAPACITY, 
                                             rotordiam=TURBINE_ROTOR_DIAMETER,
                                             loss=0.0) # Assume no losses for this simple example

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.rc('font',size=18)

fig,ax = plt.subplots(ncols=2, gridspec_kw=dict(wspace=0.25), figsize=(15,5))
ax[0].plot(windspeeds)
ax[0].set_ylabel("Wind Speed [m/s]")
ax[0].set_xlabel("Time Step")
ax[0].grid()
ax[0].set_ylim(0,14)

ax[1].plot(capacity_factors)
ax[1].set_ylabel("Capacity Factor")
ax[1].set_xlabel("Time Step")
ax[1].grid()
ax[1].set_ylim(0,1.05)
plt.show()
