# %% [markdown]
# # Solar PV Module Access

# %%
import reskit as rk
from reskit import solarpower

# %%
# Access Modules from PVLib
solarpower.SolarLibrary.modules('cec').head()
# Out:
#                      BIPV       Date  T_NOCT    A_c  N_s  I_sc_ref  V_oc_ref  \
# Name
# 1Soltech 1STH-215-P     N  10/7/2010    47.4  1.567   60      7.84      36.3
# 1Soltech 1STH-220-P     N  10/4/2010    47.4  1.567   60      7.97      36.6
# 1Soltech 1STH-225-P     N  10/4/2010    47.4  1.567   60      8.09      36.9
# 1Soltech 1STH-230-P     N  10/4/2010    47.4  1.567   60      8.18      37.1
# 1Soltech 1STH-235-WH    N   3/4/2010    49.9  1.635   60      8.54      37.0
#
#                       I_mp_ref  V_mp_ref  alpha_sc  ...   a_ref  I_L_ref  \
# Name                                                ...
# 1Soltech 1STH-215-P       7.35      29.0  0.007997  ...  1.6413    7.843
# 1Soltech 1STH-220-P       7.47      29.3  0.008129  ...  1.6572    7.974
# 1Soltech 1STH-225-P       7.58      29.6  0.008252  ...  1.6732    8.094
# 1Soltech 1STH-230-P       7.65      29.9  0.008344  ...  1.6888    8.185
# 1Soltech 1STH-235-WH      8.02      29.3  0.007430  ...  1.6292    8.543
#
# ...

# %%
# Access Single Modules
solarpower.SolarLibrary.modules('cec').loc['1Soltech 1STH-345-WH']
# Out:
# BIPV                  N
# Date          9/15/2011
# T_NOCT             47.3
# A_c               2.142
# N_s                  80
# I_sc_ref           9.26
# V_oc_ref           51.3
# I_mp_ref           8.11
# V_mp_ref           42.5
# alpha_sc       0.008334
# beta_oc        -0.18468
# a_ref            2.4912
# I_L_ref           9.288
# I_o_ref       9.623e-09
# R_s               0.186
# R_sh_ref          60.56
# Adjust               32
# gamma_r           -0.51
# Version           MM107
# PTC               304.5
# Technology    Mono-c-Si
# Name: 1Soltech 1STH-345-WH, dtype: object
